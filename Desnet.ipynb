# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.13)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.26.15)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
! mkdir ~/.kaggle
! cp '/content/drive/MyDrive/kaggle.json' ~/.kaggle
! chmod 600 ~/.kaggle/kaggle.json

# %%
drive_project_folder_path='/content/drive/MyDrive/CAPSTONE_PROJECT_MLAI'

# %%
! kaggle datasets download shyambhu/hands-and-palm-images-dataset
! cp -r  "/content/hands-and-palm-images-dataset.zip" "/content/drive/MyDrive/CAPSTONE_PROJECT_MLAI/hands-and-palm-images-dataset.zip"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 169, in authenticate
#     self._load_config(config_data)
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 210, in _load_config
#     raise ValueError('Error: Missing %s in configuration.' % item)
# ValueError: Error: Missing username in configuration.
# cp: cannot stat '/content/hands-and-palm-images-dataset.zip': No such file or directory

# %%
# !unzip hands-and-palm-images-dataset.zip
# Out:
# unzip:  cannot find or open hands-and-palm-images-dataset.zip, hands-and-palm-images-dataset.zip.zip or hands-and-palm-images-dataset.zip.ZIP.

# %%
from tensorflow.keras.utils import image_dataset_from_directory
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-0f922a082bd8> in <cell line: 1>()
# ----> 1 from tensorflow.keras.utils import image_dataset_from_directory
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/__init__.py in <module>
#      49 from ._api.v2 import autograph
#      50 from ._api.v2 import bitwise
# ---> 51 from ._api.v2 import compat
#      52 from ._api.v2 import config
#      53 from ._api.v2 import data
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/__init__.py in <module>
#      35 import sys as _sys
#      36
# ---> 37 from . import v1
#      38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v1/__init__.py in <module>
#      29 from . import autograph
#      30 from . import bitwise
# ---> 31 from . import compat
#      32 from . import config
#      33 from . import data
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v1/compat/__init__.py in <module>
#      36
#      37 from . import v1
# ---> 38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      40 from tensorflow.python.compat.compat import forward_compatible
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v1/compat/v2/__init__.py in <module>
#      26
#      27 from . import compat
# ---> 28 from tensorflow._api.v2.compat.v2 import __internal__
#      29 from tensorflow._api.v2.compat.v2 import __operators__
#      30 from tensorflow._api.v2.compat.v2 import audio
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v2/__init__.py in <module>
#      31 from . import autograph
#      32 from . import bitwise
# ---> 33 from . import compat
#      34 from . import config
#      35 from . import data
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v2/compat/__init__.py in <module>
#      36
#      37 from . import v1
# ---> 38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      40 from tensorflow.python.compat.compat import forward_compatible
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v2/compat/v2/__init__.py in <module>
#     330 _current_module = _sys.modules[__name__]
#     331 try:
# --> 332   from tensorboard.summary._tf import summary
#     333   _current_module.__path__ = (
#     334       [_module_util.get_parent_dir(summary)] + _current_module.__path__)
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/__init__.py in <module>
#      20 # If the V1 summary API is accessible, load and re-export it here.
#      21 try:
# ---> 22     from tensorboard.summary import v1  # noqa: F401
#      23 except ImportError:
#      24     pass
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/v1.py in <module>
#      22 from tensorboard.plugins.custom_scalar import summary as _custom_scalar_summary
#      23 from tensorboard.plugins.histogram import summary as _histogram_summary
# ---> 24 from tensorboard.plugins.image import summary as _image_summary
#      25 from tensorboard.plugins.pr_curve import summary as _pr_curve_summary
#      26 from tensorboard.plugins.scalar import summary as _scalar_summary
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/plugins/image/summary.py in <module>
#      26
#      27 from tensorboard.plugins.image import metadata
# ---> 28 from tensorboard.plugins.image import summary_v2
#      29 from tensorboard.util import encoder
#      30
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
import pandas as pd
dataset_dir_path='/content/Hands/Hands'
df=pd.read_csv('HandInfo.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11076 entries, 0 to 11075
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              11076 non-null  int64
#  1   age             11076 non-null  int64
#  2   gender          11076 non-null  object
#  3   skinColor       11076 non-null  object
#  4   accessories     11076 non-null  int64
#  5   nailPolish      11076 non-null  int64
#  6   aspectOfHand    11076 non-null  object
#  7   imageName       11076 non-null  object
#  8   irregularities  11076 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 778.9+ KB

# %%
def get_col_val_list_in_alphabetical_order_file_names_dict(dataset_dir_path,csv_df):

    '''
    this function is needed in order to make the list of target labels to give as labels argument of
     the keras.utils.image_dataset_from_directory function.
     The keras.utils.image_dataset_from_directory function makes a tensorflow dataset object from the images inside
     a folder. the labels argument should be a list of target variables corresponding to images filenames as listed by
     os.walk('dataset_directory_path') function.

    So what this function does is, to output a dictionary. The dictionary takes the column names in the HandInfo.csv as keys.
    The value in the dictionary corresponding to the column name given as key in the dictionary, is a list,
    containing all the rows in the csv for that single column. The thing is the the rows in this list are ordered such
    that they correspond to the image_file in the order outputted by os.walk('dataset_directory_path').





    '''
    df=csv_df.set_index('imageName')

    from os import walk ## see https://hyp.is/DAhG1PfzEe2Qw3vXNIwQ3Q/www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
    # print(list(walk(dataset_dir_path))[0][2][0])
    img_filenames_list=list(walk(dataset_dir_path))[0][2]
    col_val_list_in_order_file_names_dict={}


    for col in df.columns.to_list():
        col_val_list_in_order_file_names_dict[col]=[]

        for filename in img_filenames_list:

            col_val_list_in_order_file_names_dict[col].append(df[col][filename])
    return col_val_list_in_order_file_names_dict


### execute the function to get the dictionary
col_val_list_in_order_file_names_dict=get_col_val_list_in_alphabetical_order_file_names_dict(dataset_dir_path,csv_df=df)

# %%
### get the num of color channels in the images
def find_num_channels_in_imgs(dataset_dir_path):
    from os import walk ## see https://hyp.is/DAhG1PfzEe2Qw3vXNIwQ3Q/www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

    import cv2
    first_img_np=cv2.imread(f'{dataset_dir_path}/{list(walk(dataset_dir_path))[0][2][0]}')
    return first_img_np.shape[-1]
num_channels=find_num_channels_in_imgs(dataset_dir_path)

# %%
### to get target labels for image_files in order as listed by os.walk('dataset_directory_path')
### in order to use it in keras.utils.image_dataset_from_directory
y_gen_nonenc=col_val_list_in_order_file_names_dict['gender']

### function to encode y_gen_nonenc to binary values
def encode_labels(y_nonenc,categories_list):
    from sklearn.preprocessing import OrdinalEncoder
    y_nonenc=np.array(y_nonenc).reshape(-1,1)
    oe=OrdinalEncoder(categories=[categories_list]) ## so that we know which category is 0 and 1; here male will be encoded as 0 and female 1
    y_enc_np=oe.fit_transform(y_nonenc)
    return y_enc_np

y_gen_enc_np=encode_labels(y_gen_nonenc,['male','female'])

# %%
img_resize_shape=(240,320)
img_size_tuple=(img_resize_shape[0],img_resize_shape[1],num_channels)

test_fraction=0.2
seed=12
'''
The keras.utils.image_dataset_from_directory function makes a tensorflow dataset object from the images inside
a folder.
see https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
 the labels argument should be a list of target variables corresponding to images filenames as listed by
os.walk('dataset_directory_path') function.
'''

train_img_set_tfds, test_img_set_tfds=image_dataset_from_directory(
    dataset_dir_path,
    labels=y_gen_enc_np.flatten().tolist(),
    # labels=None,

    validation_split=test_fraction,
    subset='both',
    seed=seed,
    image_size=img_resize_shape,
    batch_size=8
    )

### to make a smaller dataset to do trial and error training ; so that the epochs will finish faster
small_train=train_img_set_tfds.take(400) ## 400 is the number of batches
# Out:
# Found 11076 files belonging to 2 classes.
# Using 8861 files for training.
# Using 2215 files for validation.

# %%
### just to check if the contents of the tensorflow dataset obj are correct and  as intended

'''
count=0
for i,j in small_train:
    count+=1
    if count==1:
        print(i.numpy().shape) ### (batch_size, img_height, img_width, channels)
        print(j.numpy()) ## outputs labels for one batch

    else:
        break
# print(count)
'''
# Out:
# '\ncount=0\nfor i,j in small_train:\n    count+=1\n    if count==1:\n        print(i.numpy().shape) ### (batch_size, img_height, img_width, channels)\n        print(j.numpy()) ## outputs labels for one batch\n\n    else:\n        break\n# print(count)\n'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Input, Dense, concatenate, Conv2D, MaxPooling2D, Dropout, Rescaling, RandomFlip, RandomRotation

# %%
# !pip install keras_cv &> /dev/null
import keras_cv

# %%
img_size_tuple=(img_resize_shape[0],img_resize_shape[1],num_channels)

print(img_size_tuple )
# Out:
# (240, 320, 3)

# %%
small_train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 240, 320, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
test_img_set_tfds
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 240, 320, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
import tensorflow.keras as keras

# %% [markdown]
# Densenet code

# %%
'''
Dense net is densely connected-convolutional networks.
DenseNet was specially developed to improve accuracy caused by the vanishing gradient in high-level neural networks due to the long distance between input and output layers &
the information vanishes before reaching its destination.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras import Model

# %%
'''
The dense_block function is a key component of the DenseNet architecture. It defines a block that consists of multiple dense layers.
The purpose of the dense_block function is to create a block of dense layers within the DenseNet architecture.
By stacking multiple instances of this block together, the network can effectively learn feature representations at different scales and depths, promoting information flow and gradient propagation throughout the network.
'''

# %%
def dense_block(x, growth_rate, num_layers):
    for _ in range(num_layers):
        # Bottleneck layer
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(4 * growth_rate, kernel_size=(1, 1), padding='same')(x)  #1*1 convolution

        # Composite function
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(growth_rate, kernel_size=(3, 3), padding='same')(x)

        # Concatenate with input
        x = tf.keras.layers.Concatenate()([x, x])
    return x

# %%
#The transition_block function defines a block that performs a transition between two dense blocks by reducing the spatial dimensions and the number of channels.
'''
The purpose of the transition_block function is to introduce a transition between two dense blocks in the DenseNet architecture.
It compresses the information and reduces the spatial dimensions, allowing for a more compact representation and aiding in the efficient flow of information through the network.
'''
def transition_block(x, reduction):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(int(tf.keras.backend.int_shape(x)[3] * reduction), kernel_size=(1, 1), padding='same')(x)
    x = AveragePooling2D(pool_size=(2, 2), strides=2)(x)
    return x

# %%
'''
The create_densenet function is used to create a DenseNet model given the input shape, number of classes, growth rate, number of blocks, and reduction factor.
'''

def create_densenet(input_shape, num_classes, growth_rate=32, num_blocks=[6, 12, 24, 16], reduction=0.5):  # 4 dense blocks with layers as 6,12,24,16 respectively
    inputs = tf.keras.Input(shape=input_shape)

    # Initial convolution
    x = Conv2D(2 * growth_rate, kernel_size=(7, 7), strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)

    # Dense blocks and transition blocks
    for block in num_blocks:
        x = dense_block(x, growth_rate, block)
        x = transition_block(x, reduction)

    # Final blocks
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)

    # Classification layer
    x = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=x)
    return model

# %%
# Create the DenseNet model
input_shape = (240, 320, 3)  #according to image size
num_classes = 2  # two genders, male and female
model = create_densenet(input_shape, num_classes)

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Print the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 240, 320, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 120, 160, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 120, 160, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 120, 160, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 60, 80, 64)   0           ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 60, 80, 64)  256         ['max_pooling2d[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 60, 80, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 60, 80, 128)  8320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 60, 80, 128)  512        ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 60, 80, 128)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 60, 80, 32)   36896       ['activation_2[0][0]']
#
#  concatenate (Concatenate)      (None, 60, 80, 64)   0           ['conv2d_2[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 60, 80, 64)  256         ['concatenate[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 60, 80, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 60, 80, 128)  8320        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 60, 80, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 60, 80, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 60, 80, 32)   36896       ['activation_4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 60, 80, 64)   0           ['conv2d_4[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 60, 80, 64)  256         ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 60, 80, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 60, 80, 128)  8320        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 60, 80, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 60, 80, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 60, 80, 32)   36896       ['activation_6[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 60, 80, 64)   0           ['conv2d_6[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 60, 80, 64)  256         ['concatenate_2[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 60, 80, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 60, 80, 128)  8320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 60, 80, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 60, 80, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 60, 80, 32)   36896       ['activation_8[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 60, 80, 64)   0           ['conv2d_8[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 60, 80, 64)  256         ['concatenate_3[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 60, 80, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 60, 80, 128)  8320        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 60, 80, 128)  512        ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 60, 80, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 60, 80, 32)   36896       ['activation_10[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 60, 80, 64)   0           ['conv2d_10[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 60, 80, 64)  256         ['concatenate_4[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 60, 80, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 60, 80, 128)  8320        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 60, 80, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 60, 80, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 60, 80, 32)   36896       ['activation_12[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 60, 80, 64)   0           ['conv2d_12[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 60, 80, 64)  256         ['concatenate_5[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 60, 80, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 60, 80, 32)   2080        ['activation_13[0][0]']
#
#  average_pooling2d (AveragePool  (None, 30, 40, 32)  0           ['conv2d_13[0][0]']
#  ing2D)
#
#  batch_normalization_14 (BatchN  (None, 30, 40, 32)  128         ['average_pooling2d[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 30, 40, 32)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 30, 40, 128)  4224        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 30, 40, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 30, 40, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 30, 40, 32)   36896       ['activation_15[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 30, 40, 64)   0           ['conv2d_15[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 30, 40, 64)  256         ['concatenate_6[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 30, 40, 64)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 30, 40, 128)  8320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 30, 40, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 30, 40, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 30, 40, 32)   36896       ['activation_17[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 30, 40, 64)   0           ['conv2d_17[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 30, 40, 64)  256         ['concatenate_7[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None,
0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 7, 10, 64)    0           ['batch_normalization_106[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 7, 10, 128)   8320        ['activation_106[0][0]']
#
#  batch_normalization_107 (Batch  (None, 7, 10, 128)  512         ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 7, 10, 128)   0           ['batch_normalization_107[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 7, 10, 32)    36896       ['activation_107[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 7, 10, 64)    0           ['conv2d_107[0][0]',
#                                                                   'conv2d_107[0][0]']
#
#  batch_normalization_108 (Batch  (None, 7, 10, 64)   256         ['concatenate_51[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 7, 10, 64)    0           ['batch_normalization_108[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 7, 10, 128)   8320        ['activation_108[0][0]']
#
#  batch_normalization_109 (Batch  (None, 7, 10, 128)  512         ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 7, 10, 128)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 10, 32)    36896       ['activation_109[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 7, 10, 64)    0           ['conv2d_109[0][0]',
#                                                                   'conv2d_109[0][0]']
#
#  batch_normalization_110 (Batch  (None, 7, 10, 64)   256         ['concatenate_52[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 7, 10, 64)    0           ['batch_normalization_110[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 10, 128)   8320        ['activation_110[0][0]']
#
#  batch_normalization_111 (Batch  (None, 7, 10, 128)  512         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 7, 10, 128)   0           ['batch_normalization_111[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 7, 10, 32)    36896       ['activation_111[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 7, 10, 64)    0           ['conv2d_111[0][0]',
#                                                                   'conv2d_111[0][0]']
#
#  batch_normalization_112 (Batch  (None, 7, 10, 64)   256         ['concatenate_53[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 7, 10, 64)    0           ['batch_normalization_112[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 7, 10, 128)   8320        ['activation_112[0][0]']
#
#  batch_normalization_113 (Batch  (None, 7, 10, 128)  512         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 7, 10, 128)   0           ['batch_normalization_113[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 10, 32)    36896       ['activation_113[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 7, 10, 64)    0           ['conv2d_113[0][0]',
#                                                                   'conv2d_113[0][0]']
#
#  batch_normalization_114 (Batch  (None, 7, 10, 64)   256         ['concatenate_54[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 7, 10, 64)    0           ['batch_normalization_114[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 7, 10, 128)   8320        ['activation_114[0][0]']
#
#  batch_normalization_115 (Batch  (None, 7, 10, 128)  512         ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 7, 10, 128)   0           ['batch_normalization_115[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 7, 10, 32)    36896       ['activation_115[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 7, 10, 64)    0           ['conv2d_115[0][0]',
#                                                                   'conv2d_115[0][0]']
#
#  batch_normalization_116 (Batch  (None, 7, 10, 64)   256         ['concatenate_55[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 7, 10, 64)    0           ['batch_normalization_116[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 7, 10, 128)   8320        ['activation_116[0][0]']
#
#  batch_normalization_117 (Batch  (None, 7, 10, 128)  512         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_117 (Activation)    (None, 7, 10, 128)   0           ['batch_normalization_117[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 7, 10, 32)    36896       ['activation_117[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 7, 10, 64)    0           ['conv2d_117[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  batch_normalization_118 (Batch  (None, 7, 10, 64)   256         ['concatenate_56[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 7, 10, 64)    0           ['batch_normalization_118[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 7, 10, 128)   8320        ['activation_118[0][0]']
#
#  batch_normalization_119 (Batch  (None, 7, 10, 128)  512         ['conv2d_118[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 7, 10, 128)   0           ['batch_normalization_119[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 7, 10, 32)    36896       ['activation_119[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 7, 10, 64)    0           ['conv2d_119[0][0]',
#                                                                   'conv2d_119[0][0]']
#
#  batch_normalization_120 (Batch  (None, 7, 10, 64)   256         ['concatenate_57[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 7, 10, 64)    0           ['batch_normalization_120[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 7, 10, 32)    2080        ['activation_120[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 3, 5, 32)    0           ['conv2d_120[0][0]']
#  oling2D)
#
#  batch_normalization_121 (Batch  (None, 3, 5, 32)    128         ['average_pooling2d_3[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 3, 5, 32)     0           ['batch_normalization_121[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['activation_121[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            66          ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 2,673,666
# Trainable params: 2,650,882
# Non-trainable params: 22,784
# __________________________________________________________________________________________________

# %%
model.fit(
    # train_img_set_tfds,
    small_train,
    # y=y_gen_enc,
    epochs=50,
    validation_data=test_img_set_tfds,
    # batch_size=5,
    class_weight={0:(1/3967), 1:(1/7109)}
    #callbacks=[callbacks_list]
)
# Out:
# Epoch 1/50
# 400/400 [==============================] - 179s 200ms/step - loss: 1.2628e-04 - accuracy: 0.5681 - val_loss: 0.6951 - val_accuracy: 0.3661
# Epoch 2/50
# 400/400 [==============================] - 78s 193ms/step - loss: 1.2499e-04 - accuracy: 0.5691 - val_loss: 1.5542 - val_accuracy: 0.6099
# Epoch 3/50
# 400/400 [==============================] - 72s 179ms/step - loss: 1.2507e-04 - accuracy: 0.5450 - val_loss: 0.9043 - val_accuracy: 0.3670
# Epoch 4/50
# 400/400 [==============================] - 77s 193ms/step - loss: 1.2474e-04 - accuracy: 0.5516 - val_loss: 0.7501 - val_accuracy: 0.6321
# Epoch 5/50
# 400/400 [==============================] - 78s 194ms/step - loss: 1.2469e-04 - accuracy: 0.5844 - val_loss: 0.7085 - val_accuracy: 0.6330
# Epoch 6/50
# 400/400 [==============================] - 77s 191ms/step - loss: 1.2470e-04 - accuracy: 0.5813 - val_loss: 0.7055 - val_accuracy: 0.6330
# Epoch 7/50
# 400/400 [==============================] - 69s 171ms/step - loss: 1.2482e-04 - accuracy: 0.5838 - val_loss: 0.7942 - val_accuracy: 0.6321
# Epoch 8/50
# 400/400 [==============================] - 68s 170ms/step - loss: 1.2476e-04 - accuracy: 0.5456 - val_loss: 0.7141 - val_accuracy: 0.6330
# Epoch 9/50
# 400/400 [==============================] - 70s 173ms/step - loss: 1.2475e-04 - accuracy: 0.5512 - val_loss: 0.6907 - val_accuracy: 0.6339
# Epoch 10/50
# 400/400 [==============================] - 70s 174ms/step - loss: 1.2467e-04 - accuracy: 0.5703 - val_loss: 0.9796 - val_accuracy: 0.6330
# Epoch 11/50
# 400/400 [==============================] - 68s 170ms/step - loss: 1.2464e-04 - accuracy: 0.6075 - val_loss: 0.6963 - val_accuracy: 0.6330
